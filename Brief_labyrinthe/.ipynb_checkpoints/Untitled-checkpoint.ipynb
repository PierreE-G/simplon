# %%
import numpy as np
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans

# %%
n = 100
n2 = -100

# %%
data = np.random.randint(0,n,(n,2))
data2 = np.random.randint(n2,0,(n,2))

# %%
#print(data)

# %%
scaler=StandardScaler()
scaler_data = scaler.fit_transform(data)

# %%
#print(scaler_data)

# %%
plt.scatter(data[:,0],data[:,1])

# %%
plt.scatter(scaler_data[:,0],scaler_data[:,1])

# %%
plt.scatter(data[:,0],data[:,1])
# Out:
# [<matplotlib.lines.Line2D at 0x7f08225c5310>,
#  <matplotlib.lines.Line2D at 0x7f08225c5400>]

# %%
X = np.concatenate((data,data2))

# %%
plt.scatter(X[:,0],X[:,1])

# %%
k=KMeans(n_clusters=2, random_state=0)
