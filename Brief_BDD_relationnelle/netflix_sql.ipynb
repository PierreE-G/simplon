# %%
import chardet
import pandas as pd
import numpy as  np

# %%
f=open('Netflix_Shows.csv','rb')

# %%
result=chardet.detect(f.read())

# %%
result
# Out:
# {'encoding': 'Windows-1252', 'confidence': 0.7280777965086309, 'language': ''}

# %%
netShow=pd.read_csv('Netflix_Shows.csv',encoding='Windows-1252')

# %%
netShow
# Out:
#                        title rating  \
# 0               White Chicks  PG-13
# 1        Lucky Number Slevin      R
# 2             Grey's Anatomy  TV-14
# 3               Prison Break  TV-14
# 4      How I Met Your Mother  TV-PG
# ..                       ...    ...
# 995                  The BFG     PG
# 996  The Secret Life of Pets     PG
# 997         Precious Puppies   TV-G
# 998              Beary Tales   TV-G
# 999          Growing Up Wild      G
#
#                                            ratingLevel  ratingDescription  \
# 0    crude and sexual humor, language and some drug...                 80
# 1    strong violence, sexual content and adult lang...                100
# 2    Parents strongly cautioned. May be unsuitable ...                 90
# 3    Parents strongly cautioned. May be unsuitable ...                 90
# 4    Parental guidance suggested. May not be suitab...                 70
# ..                                                 ...                ...
# ...

# %% [raw]
# netShow = netShow.replace(np.nan," ")
# netShow

# %%
for column in netShow.columns:
   # if (column!='show_id') & (column!='release_year'):
    if (column=='title')| (column=='rating')| (column=='ratingLevel'):
       print(column,':', netShow[column].map(lambda x: len(x)).max())
# Out:
# title : 63
# rating : 8
# ratingLevel : 125

# %%
netTitle = pd.read_csv('netflix_titles.csv')

# %%
netTitle
# Out:
#        show_id     type                                        title  \
# 0     81145628    Movie      Norm of the North: King Sized Adventure
# 1     80117401    Movie                   Jandino: Whatever it Takes
# 2     70234439  TV Show                           Transformers Prime
# 3     80058654  TV Show             Transformers: Robots in Disguise
# 4     80125979    Movie                                 #realityhigh
# ...        ...      ...                                          ...
# 6229  80000063  TV Show                                 Red vs. Blue
# 6230  70286564  TV Show                                        Maron
# 6231  80116008    Movie       Little Baby Bum: Nursery Rhyme Friends
# 6232  70281022  TV Show  A Young Doctor's Notebook and Other Stories
# 6233  70153404  TV Show                                      Friends
#
#                       director  \
# 0     Richard Finn, Tim Maltby
# 1                          NaN
# 2                          NaN
# ...

# %%
netTitle = netTitle.replace(np.nan," ")

# %%
for column in netTitle.columns:
     if (column!='show_id') & (column!='release_year'):
    #if (column=='title')| (column=='rating')| (column=='ratingLevel'):
       print(column,':', netTitle[column].map(lambda x: len(x)).max())
# Out:
# type : 7
# title : 104
# director : 208
# cast : 771
# country : 123
# date_added : 19
# rating : 8
# duration : 10
# listed_in : 79
# description : 248
