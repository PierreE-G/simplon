# %%
#Import de données
import pandas as pd
data = pd.read_csv("SMSSpamCollection.txt", sep="\t", header=None)
data[0]



#df = open('SMSSpamCollection.txt', 'r')
#data =df.read()
#print (data)
# Out:
# 0        ham
# 1        ham
# 2       spam
# 3        ham
# 4        ham
#         ...
# 5567    spam
# 5568     ham
# 5569     ham
# 5570     ham
# 5571     ham
# Name: 0, Length: 5572, dtype: object

# %%
data.info
# Out:
# <bound method DataFrame.info of          0                                                  1
# 0      ham  Go until jurong point, crazy.. Available only ...
# 1      ham                      Ok lar... Joking wif u oni...
# 2     spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3      ham  U dun say so early hor... U c already then say...
# 4      ham  Nah I don't think he goes to usf, he lives aro...
# ...    ...                                                ...
# 5567  spam  This is the 2nd time we have tried 2 contact u...
# 5568   ham               Will ü b going to esplanade fr home?
# 5569   ham  Pity, * was in mood for that. So...any other s...
# 5570   ham  The guy did some bitching but I acted like i'd...
# 5571   ham                         Rofl. Its true to its name
#
# [5572 rows x 2 columns]>

# %%
import numpy as np
np.array(data[0])
list(data[0]) #liste des targets
# Out:
# ['ham',
#  'ham',
#  'spam',
#  'ham',
#  'ham',
#  'spam',
#  'ham',
#  'ham',
#  'spam',
#  'spam',
#  'ham',
#  'spam',
#  'spam',
#  'ham',
#  'ham',
#  'spam',
#  'ham',
#  'ham',
#  'ham',
#  'spam',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'spam',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'spam',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'spam',
#  'ham',
#  'spam',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'spam',
#  'ham',
#  'spam',
#  'spam',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'spam',
#  'ham',
#  'spam',
#  'ham',
#  'ham',
# ...

# %%
Y = targets = np.array(data[0])
corpus = np.array (data[1])
targets=[1 if Y== 'ham' else 0 for Y in targets]

# %%
# nettoyage de données (enlever les stopswords)
#stopwords (ensemble des mots à exclure)
import nltk
#from nltk.corpus import stopwords
stopwords = nltk.corpus.stopwords.words('english')
#print(stopwords.words('english'))

# %%
len(stopwords)
# Out:
# 179

# %%
print(stopwords)
# Out:
# ['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', "you're", "you've", "you'll", "you'd", 'your', 'yours', 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', 'she', "she's", 'her', 'hers', 'herself', 'it', "it's", 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', "that'll", 'these', 'those', 'am', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does', 'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', 'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into', 'through', 'during', 'before', 'after', 'above', 'below', 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further', 'then', 'once', 'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more', 'most', 'other', 'some', 'such', 'no', 'nor', 'not', 'only', 'own', 'same', 'so', 'than',
# ...

# %%
corpus [0]
# Out:
# 'Go until jurong point, crazy.. Available only in bugis n great world la e buffet... Cine there got amore wat...'

# %%
# tokenize : séparer les mots du 1er sms
nltk.download('punkt')
from nltk.tokenize import word_tokenize
word_tokenize(corpus[0])
# Out:
# [nltk_data] Downloading package punkt to /home/pierre-
# [nltk_data]     etienne/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# ['Go',
#  'until',
#  'jurong',
#  'point',
#  ',',
#  'crazy',
#  '..',
#  'Available',
#  'only',
#  'in',
#  'bugis',
#  'n',
#  'great',
#  'world',
#  'la',
#  'e',
#  'buffet',
#  '...',
#  'Cine',
#  'there',
#  'got',
#  'amore',
#  'wat',
#  '...']

# %%
#stop words seconde façon de faire
#import nltk
#nltk.download()

# %%
#suite seconde façon
#print(nltk.corpus.stopwords.words('english'))

# %%
# vectorisation de données
from sklearn.feature_extraction.text import TfidfVectorizer

vectorizer = TfidfVectorizer(stop_words = stopwords)
X = vectorizer.fit_transform(data [1]) #corpus

#print(vectorizer.get_feature_names())
print(X)
# affiches des tuple d'indices : ligne / colonne d'un élément + le contenu de l'élément
# Out:
#   (0, 8207)	0.19367133232870914
#   (0, 1074)	0.34662215358656684
#   (0, 3575)	0.16249778391503625
#   (0, 2036)	0.2928277960456836
#   (0, 1743)	0.3308883126306653
#   (0, 4437)	0.2928277960456836
#   (0, 8417)	0.23446293536343882
#   (0, 3615)	0.1914742686221826
#   (0, 1745)	0.2928277960456836
#   (0, 1301)	0.2592620666240387
#   (0, 2312)	0.2684349975703689
#   (0, 5871)	0.2711122263759042
#   (0, 4311)	0.34662215358656684
#   (0, 3531)	0.15700111684745632
#   (1, 5488)	0.5466243141314314
#   (1, 8322)	0.43162957585464123
#   (1, 4279)	0.5236804332035243
#   (1, 4473)	0.4083258549263009
#   (1, 5461)	0.2718944069420321
#   (2, 77)	0.23481398547774926
#   (2, 1158)	0.16878205227806695
#   (2, 6197)	0.16878205227806695
#   (2, 7876)	0.12429583820628914
#   (2, 7185)	0.1966389668741482
#   (2, 6145)	0.1787234410397601
#   :	:
#   (5567, 5714)	0.20749813661767133
#   (5567, 6197)	0.22852426188600214
#   (5568, 2959)	0.6485991737677518
#   (5568, 3322)	0.5597098620657655
# ...

# %%
type(X)# matrix sparse est utilisée pour les grosses matrices avec beaucoup de zéros
# Out:
# scipy.sparse.csr.csr_matrix

# %%
X.nonzero
# Out:
# <bound method spmatrix.nonzero of <5572x8577 sparse matrix of type '<class 'numpy.float64'>'
# 	with 47370 stored elements in Compressed Sparse Row format>>

# %%
5572*8713-74169 # Nbre de zéros dans la matrix
# Out:
# 48474667

# %%
X[5571, 7806] # Array sparse
# Out:
# 0.0

# %%
print (len(vectorizer.get_feature_names()))#taille du volcabulaire / Nbre de mots uniques dans tous les docuements
# Out:
# 8577

# %%
X.shape
# Out:
# (5572, 8577)

# %%
data[1][0] # affichage du premier element [0] du corpus
# Out:
# 'Go until jurong point, crazy.. Available only in bugis n great world la e buffet... Cine there got amore wat...'

# %%
#Quel est le type Python de vos données après vectorisation
Numerical. With "TfidfVectorizer", we  the Converted a collection of raw documents to a matrix of TF-IDF features.
# Out:
#   File "<ipython-input-20-6f2c8977f052>", line 2
#     Numerical. With "TfidfVectorizer", we  the Converted a collection of raw documents to a matrix of TF-IDF features.
#                     ^
# SyntaxError: invalid syntax

# %%
def get_top_n_words(corpus, n=None):

    vec = CountVectorizer().fit(corpus)
    bag_of_words = vec.transform(corpus)
    sum_words = bag_of_words.sum(axis=0) 
    words_freq = [(word, sum_words[0, idx]) for word, idx in     vec.vocabulary_.items()]
    words_freq =sorted(words_freq, key = lambda x: x[1], reverse=True)
    return words_freq[:n]

# %%
from sklearn.feature_extraction.text import CountVectorizer
vectorizer = CountVectorizer(stop_words = stopwords).fit(corpus)
XCount = vectorizer.fit_transform(corpus)
print(vectorizer.get_feature_names())

# %%
#Quelle sont les 10 mots les plus fréquent dans le jeux de données ?

def get_top_n_words(corpus, n=None):
    vec = CountVectorizer(stop_words = stopwords).fit(corpus)
    bag_of_words = vec.transform (corpus)
    sum_words = bag_of_words.sum(axis=0)
    words_freq = [(word, sum_words[0,idx])for word, idx in vec.vocabulary_.items()]
    words_freq = sorted (words_freq, key=lambda x:x[1], reverse=True)
    return words_freq[:n]

# %%
get_top_n_words(corpus, n=10)

# %%
#Les moins fréquents ?
def get_bottom_n_words(corpus, n=None):
    vec = CountVectorizer(stop_words = stopwords).fit(corpus)
    bag_of_words = vec.transform (corpus)
    sum_words = bag_of_words.sum(axis=0)
    words_freq = [(word, sum_words[0,idx])for word, idx in vec.vocabulary_.items()]
    words_freq = sorted (words_freq, key=lambda x:x[1], reverse=False)
    return words_freq[:n]

# %%
get_bottom_n_words(corpus, n=10)

# %%
# Tracer la distribution de la fréquence des mots présents dans le jeux de données. Qu'observez vous ?r
# regarder le nbre de fréquences de mots // matpotlib (bar) / seaborn

# %% [markdown]
# 3) Apprenstissage
# Que représente la mesure f1 ? Quelles sont ces avantages sur d'autre mesure tel que la précision le rappel ou l'accuracy ?
# 3) Veille cross validation https://scikit-learn.org/stable/modules/cross_validation.html
# Utilisez la méthode de ShuffleSplit pour construire vos jeux de données permettant la validation croisée.

# %%
# Régression logistique
# Build train and test datasets for single class classification


from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split (X, Y, test_size=0.2, random_state= 42)

rtrain = X_train.shape[0]/X.shape[0]
rtest = X_test.shape[0]/X.shape[0]
print("train size ratio: %s" %(rtrain))
print("train size ratio: %s" %(rtest))
print("train size ratio: {}%".format(round(rtest,2)))

# %%
model = LogisticRegression(test_size=0.2, random_state= 42)
start = time()
model.fit(X_train, y_train)
T1 = time() - start

S = model.score(X_train, y_train)
S1 = round(model.score(X_tesy, y_test),4)

# %%
#svm

# %% [markdown]
# 4) Train
# Fit the models and compare the performance in a table that show
# the mean of the f1 score
# the standard deviation of the f1 score
